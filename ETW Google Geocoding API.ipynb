# %%
#### Google Geocoding API
#### Y. Rooseleer, BiASC
#### => API Calls, Request/Response, Authentication, Data Management/Filtering/Selecting/Transforming
import requests
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print('Imported libraries for the script')
print('STARTING Google Geocoding API Example Script')
print('=> API Calls, Request/Response, Authentication, Data Management/Filtering/Selecting/Transforming')
#dir(urllib)
#dir(requests)
# Out:
# Current date and time:
# 2020-11-19 09:15:22.574547
# Imported libraries for the script
# STARTING Google Geocoding API Example Script
# => API Calls, Request/Response, Authentication, Data Management/Filtering/Selecting/Transforming

# %%
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print('Getting input')
#####
address = input("Town or City? ")
# Out:
# Current date and time:
# 2020-11-19 09:15:24.633987
# Getting input
# Town or City? Zaventem

# %%
import datetime
import requests
import json
print ("Current date and time: ")
print(datetime.datetime.now())
api_scheme = "https://"
api_authority = "maps.googleapis.com"
api_path = "/maps/api/geocode/json"
main_api = api_scheme + api_authority + api_path
#main_api = "https://maps.googleapis.com/maps/api/geocode/json"
api_key = "AIzaSyAbs6bmOVHY5qMft5lw-SIK4FpMOOqXW7Y"
api_query = "?"+"key"+"="+api_key+"&"+"address"+"="+address
uri = main_api + api_query
# uri = main_api+"?"+"key"+"="+api_key+"&"+"address"+"="+address
print('Creating full request')
print(uri)
resp  = requests.get(uri)
print("------1--------")
print(type(resp))
#print(dir(resp))
#print(dir(requests.adapters))
#print(resp.__dict__)
print("------2--------")
print(resp.status_code)
print("------3--------")
print(resp.text)
print("------4--------")
json_data = resp.json()
print(type(json_data))
print("------5--------")
print(json_data)
#print("------6--------")
#str_doc = json.dumps(json_data, indent=4)
#print(str_doc)
# Out:
# Current date and time:
# 2020-11-19 09:15:31.601896
# Creating full request
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAbs6bmOVHY5qMft5lw-SIK4FpMOOqXW7Y&address=Zaventem
# ------1--------
# <class 'requests.models.Response'>
# ------2--------
# 200
# ------3--------
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Zaventem",
#                "short_name" : "Zaventem",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Flemish Brabant",
#                "short_name" : "VB",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Flanders",
#                "short_name" : "Flanders",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Belgium",
#                "short_name" : "BE",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Zaventem, Belgium",
#          "geometry" : {
#             "bounds" : {
#                "northeast" : {
#                   "lat" : 50.9025,
#                   "lng" : 4.53644
#                },
#                "southwest" : {
#                   "lat" : 50.83412,
#                   "lng" : 4.4205201
#                }
#             },
#             "location" : {
#                "lat" : 50.8854878,
#                "lng" : 4.4709968
#             },
#             "location_type" : "APPROXIMATE",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 50.9025,
#                   "lng" : 4.53644
#                },
#                "southwest" : {
#                   "lat" : 50.83412,
#                   "lng" : 4.4205201
#                }
#             }
#          },
#          "place_id" : "ChIJByU7kUPcw0cRsF9NL6uZAAQ",
#          "types" : [ "locality", "political" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# ------4--------
# <class 'dict'>
# ------5--------
# {'results': [{'address_components': [{'long_name': 'Zaventem', 'short_name': 'Zaventem', 'types': ['locality', 'political']}, {'long_name': 'Flemish Brabant', 'short_name': 'VB', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Flanders', 'short_name': 'Flanders', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Belgium', 'short_name': 'BE', 'types': ['country', 'political']}], 'formatted_address': 'Zaventem, Belgium', 'geometry': {'bounds': {'northeast': {'lat': 50.9025, 'lng': 4.53644}, 'southwest': {'lat': 50.83412, 'lng': 4.4205201}}, 'location': {'lat': 50.8854878, 'lng': 4.4709968}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 50.9025, 'lng': 4.53644}, 'southwest': {'lat': 50.83412, 'lng': 4.4205201}}}, 'place_id': 'ChIJByU7kUPcw0cRsF9NL6uZAAQ', 'types': ['locality', 'political']}], 'status': 'OK'}

# %%
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print('Success of the request')
print("STATUS")
print('------1--------')
print(resp.status_code)
print('------2-------')
json_status = json_data["status"]
#print("API Status: " + json_status)
print(json_status)
print('------3-------')
alternative = resp.json()["status"]
print(alternative)
# Out:
# Current date and time:
# 2020-11-19 09:15:36.995106
# Success of the request
# STATUS
# ------1--------
# 200
# ------2-------
# OK
# ------3-------
# OK

# %%
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print('Raw result of the request')
if resp.status_code == 200:
    print("RAW RESULT IN JSON - STATUS CODE")
    print(resp.status_code)
if json_status == "OK":
    print("RAW RESULT IN JSON - STATUS TEXT")
    print( json_status )
    print('--------------')
    print(json_data)
    print('--------------')
# Out:
# Current date and time:
# 2020-11-19 09:15:39.498853
# Raw result of the request
# RAW RESULT IN JSON - STATUS CODE
# 200
# RAW RESULT IN JSON - STATUS TEXT
# OK
# --------------
# {'results': [{'address_components': [{'long_name': 'Zaventem', 'short_name': 'Zaventem', 'types': ['locality', 'political']}, {'long_name': 'Flemish Brabant', 'short_name': 'VB', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Flanders', 'short_name': 'Flanders', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Belgium', 'short_name': 'BE', 'types': ['country', 'political']}], 'formatted_address': 'Zaventem, Belgium', 'geometry': {'bounds': {'northeast': {'lat': 50.9025, 'lng': 4.53644}, 'southwest': {'lat': 50.83412, 'lng': 4.4205201}}, 'location': {'lat': 50.8854878, 'lng': 4.4709968}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 50.9025, 'lng': 4.53644}, 'southwest': {'lat': 50.83412, 'lng': 4.4205201}}}, 'place_id': 'ChIJByU7kUPcw0cRsF9NL6uZAAQ', 'types': ['locality', 'political']}], 'status': 'OK'}
# --------------

# %%
### print keys and values of a hierarchical JSON object: all parents and children
def recursive_print(src, dpth = 0, key = ''):
    """ Recursively prints nested elements."""
    tabs = lambda n: '-' * n * 1 # or 2 or 4 or 8 or...
    brace = lambda s, n: '%s%s%s' % (''*n, s, ''*n)
    #print(src)
    if isinstance(src, dict):
        for key, value in src.items():
            print(tabs(dpth) + brace(key, dpth))
            recursive_print(value, dpth + 1, key)
    elif isinstance(src, list):
        for litem in src:
            recursive_print(litem, dpth)
    else:
        if key:
            print(tabs(dpth) + '%s = %s' % (key, src))
        else:
            print(tabs(dpth) + '-%s' % src)

recursive_print(json_data)
# Out:
# results
# -address_components
# --long_name
# ---long_name = Zaventem
# --short_name
# ---short_name = Zaventem
# --types
# ----locality
# ----political
# --long_name
# ---long_name = Flemish Brabant
# --short_name
# ---short_name = VB
# --types
# ----administrative_area_level_2
# ----political
# --long_name
# ---long_name = Flanders
# --short_name
# ---short_name = Flanders
# --types
# ----administrative_area_level_1
# ----political
# --long_name
# ---long_name = Belgium
# --short_name
# ---short_name = BE
# --types
# ----country
# ----political
# -formatted_address
# --formatted_address = Zaventem, Belgium
# -geometry
# --bounds
# ---northeast
# ----lat
# -----lat = 50.9025
# ----lng
# -----lng = 4.53644
# ---southwest
# ----lat
# -----lat = 50.83412
# ----lng
# -----lng = 4.4205201
# --location
# ---lat
# ----lat = 50.8854878
# ---lng
# ----lng = 4.4709968
# --location_type
# ---location_type = APPROXIMATE
# --viewport
# ---northeast
# ----lat
# -----lat = 50.9025
# ----lng
# -----lng = 4.53644
# ---southwest
# ----lat
# -----lat = 50.83412
# ----lng
# -----lng = 4.4205201
# -place_id
# --place_id = ChIJByU7kUPcw0cRsF9NL6uZAAQ
# -types
# ---locality
# ---political
# status
# -status = OK

# %%
print("Alternative output: no values")
### print keys of a hierarchical JSON object: all parents and children
def recursive_print(src, dpth = 0, key = ''):
    """ Recursively prints nested elements."""
    tabs = lambda n: '-' * n * 1 # or 2 or 4 or 8 or...
    brace = lambda s, n: '%s%s%s' % (''*n, s, ''*n)
    #print(src)
    if isinstance(src, dict):
        for key, value in src.items():
            print(tabs(dpth) + brace(key, dpth))
            recursive_print(value, dpth + 1, key)
    elif isinstance(src, list):
        for litem in src:
            recursive_print(litem, dpth)
    else:
        if key:
            #print(tabs(dpth) + '%s = %s' % (key, src))
            print(tabs(dpth) + '%s' % (key))
        else:
            # print(tabs(dpth) + '-%s' % src)
            None

recursive_print(json_data)
# Out:
# Alternative output: no values
# results
# -address_components
# --long_name
# ---long_name
# --short_name
# ---short_name
# --types
# --long_name
# ---long_name
# --short_name
# ---short_name
# --types
# --long_name
# ---long_name
# --short_name
# ---short_name
# --types
# --long_name
# ---long_name
# --short_name
# ---short_name
# --types
# -formatted_address
# --formatted_address
# -geometry
# --bounds
# ---northeast
# ----lat
# -----lat
# ----lng
# -----lng
# ---southwest
# ----lat
# -----lat
# ----lng
# -----lng
# --location
# ---lat
# ----lat
# ---lng
# ----lng
# --location_type
# ---location_type
# --viewport
# ---northeast
# ----lat
# -----lat
# ----lng
# -----lng
# ---southwest
# ----lat
# -----lat
# ----lng
# -----lng
# -place_id
# --place_id
# -types
# status
# -status

# %%
import yaml
yaml_data = yaml.dump(json_data)
print(yaml_data)
# Out:
# results:
# - address_components:
#   - long_name: Zaventem
#     short_name: Zaventem
#     types:
#     - locality
#     - political
#   - long_name: Flemish Brabant
#     short_name: VB
#     types:
#     - administrative_area_level_2
#     - political
#   - long_name: Flanders
#     short_name: Flanders
#     types:
#     - administrative_area_level_1
#     - political
#   - long_name: Belgium
#     short_name: BE
#     types:
#     - country
#     - political
#   formatted_address: Zaventem, Belgium
#   geometry:
#     bounds:
#       northeast:
#         lat: 50.9025
#         lng: 4.53644
#       southwest:
#         lat: 50.83412
#         lng: 4.4205201
#     location:
#       lat: 50.8854878
#       lng: 4.4709968
#     location_type: APPROXIMATE
#     viewport:
#       northeast:
#         lat: 50.9025
#         lng: 4.53644
#       southwest:
#         lat: 50.83412
#         lng: 4.4205201
#   place_id: ChIJByU7kUPcw0cRsF9NL6uZAAQ
#   types:
#   - locality
#   - political
# status: OK

# %%
print ("Current date and time: ")
print(datetime.datetime.now())
print('Filtered result of the request')
if json_status == "OK":
    print("SELECTED RESULT A ")
    print('------1-------')
    selection = json_data['results'][0]['formatted_address']
    print(selection)
    print('------2--------')
    selection = json_data['results'][0]['geometry']['location']
    print(selection)
    print('------3--------')
    selection = json_data['results'][0]['geometry']['location']['lat']
    print(selection)
    selection = json_data['results'][0]['geometry']['location']['lng']
    print(selection)
# Out:
# Current date and time:
# 2020-11-18 16:50:20.930655
# Filtered result of the request
# SELECTED RESULT A
# ------1-------
# Zaventem, Belgium
# ------2--------
# {'lat': 50.8854878, 'lng': 4.4709968}
# ------3--------
# 50.8854878
# 4.4709968

# %%
print ("Current date and time: ")
print(datetime.datetime.now())
if json_status == "OK":
    print("SELECTED RESULT B ")
    print('--------------')
    selection1 = json_data['results'][0]['address_components'][0]['long_name']
    selection2 = json_data['results'][0]['address_components'][1]['long_name']
    selection3 = json_data['results'][0]['address_components'][2]['long_name']
    selection4 = json_data['results'][0]['address_components'][3]['long_name']
    print(selection1)
    print(selection2)
    print(selection3)
    print(selection4)
    print('--------------')
# Out:
# Current date and time:
# 2020-11-18 16:50:28.680762
# SELECTED RESULT B
# --------------
# Zaventem
# Flemish Brabant
# Flanders
# Belgium
# --------------

# %%
print ("Current date and time: ")
print(datetime.datetime.now())
print("SELECTED RESULT C ")
print('--------------')
if json_status == "OK":
    print("LOOPING THROUGH RESULTS")
    for each in json_data["results"][0]["address_components"]:
        print(each["long_name"])
print('--------------')
# Out:
# Current date and time:
# 2020-11-18 16:51:25.917182
# SELECTED RESULT C
# --------------
# LOOPING THROUGH RESULTS
# Zaventem
# Flemish Brabant
# Flanders
# Belgium
# --------------
